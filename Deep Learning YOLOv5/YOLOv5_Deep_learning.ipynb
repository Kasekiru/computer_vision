# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Setup**
#
# Clone GitHub repository, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-331-gab364c98 Python-3.10.12 torch-2.3.0+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/107.7 GB disk)

# %%
# !unzip "/content/CatModel.zip"
# !unzip "/content/CatModelSharpening.zip"
# !unzip "/content/CatModelGaussianBlur.zip"
# Out:
# Archive:  /content/CatModel.zip
#    creating: CatModel/test/
#    creating: CatModel/test/images/
#   inflating: CatModel/test/images/cat-2617_jpg.rf.20366d737ac6570bbd5d7ef2e95a7079.jpg
#   inflating: CatModel/test/images/cat-2995_jpg.rf.9c18f6660ae508a490923a612ef52dac.jpg
#   inflating: CatModel/test/images/cat-3173_jpg.rf.0e861480bce72a01ebb6d278bfdd5dbe.jpg
#   inflating: CatModel/test/images/cat-3558_jpg.rf.966088ba94cfd475b6cdbbfc27f478f7.jpg
#   inflating: CatModel/test/images/cat-553_jpg.rf.cbd260603b5764362cb90d150cda5f88.jpg
#    creating: CatModel/test/labels/
#   inflating: CatModel/test/labels/cat-2617_jpg.rf.20366d737ac6570bbd5d7ef2e95a7079.txt
#   inflating: CatModel/test/labels/cat-2995_jpg.rf.9c18f6660ae508a490923a612ef52dac.txt
#   inflating: CatModel/test/labels/cat-3173_jpg.rf.0e861480bce72a01ebb6d278bfdd5dbe.txt
#   inflating: CatModel/test/labels/cat-3558_jpg.rf.966088ba94cfd475b6cdbbfc27f478f7.txt
# ...

# %%
# Train YOLOv5s on COCO128 for 20 epochs
# CatModelSharpening
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 20 --data /content/yolov5/data/data_sharpening.yaml --weights yolov5s.pt --cache
# Out:
# 2024-06-26 06:07:38.926386: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 06:07:38.926467: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 06:07:38.928339: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Train YOLOv5s on COCO128 for 20 epochs
# CatModelGaussianBlur
# !python train.py --img 640 --batch 16 --epochs 20 --data /content/yolov5/data/data_gaussianblur.yaml --weights yolov5s.pt --cache
# Out:
# 2024-06-26 07:20:41.988634: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 07:20:41.988730: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 07:20:42.097039: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Train YOLOv5s on COCO128 for 20 epochs
# CatModelOriginal
# !python train.py --img 640 --batch 16 --epochs 20 --data /content/yolov5/data/data_original.yaml --weights yolov5s.pt --cache
# Out:
# 2024-06-26 08:30:12.320190: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-26 08:30:12.320283: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-26 08:30:12.322322: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#Testing Object Detection dengan dataset preprocessing sharpening
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing1.jpg
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing2.jpg
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing3.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/teskucing1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-331-gab364c98 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/teskucing1.jpg: 320x640 1 cat, 221.6ms
# Speed: 1.0ms pre-process, 221.6ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
# ...

# %%
#Testing Object Detection dengan dataset preprocessing gaussion blur
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing1.jpg
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing2.jpg
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing3.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/yolov5/teskucing1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-331-gab364c98 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/teskucing1.jpg: 320x640 (no detections), 350.9ms
# Speed: 1.1ms pre-process, 350.9ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5
# ...

# %%
#Testing Object Detection dengan dataset original
# !python detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing1.jpg
# !python detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing2.jpg
# !python detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source /content/yolov5/teskucing3.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp4/weights/best.pt'], source=/content/yolov5/teskucing1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-331-gab364c98 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/teskucing1.jpg: 320x640 1 cat, 220.2ms
# Speed: 1.3ms pre-process, 220.2ms inference, 1.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp8
# ...
